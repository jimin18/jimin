# %% [markdown]
# <a href="https://colab.research.google.com/github/jimin18/jimin/blob/master/hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data,_ = make_blobs(n_samples=1000, centers=5, cluster_std=0.60, random_state=0)
data.shape
# Out:
# (1000, 2)

# %%
plt.plot(data[:,0], data[:,1],'.')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=1000, n_init=5, random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(data)

centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[-1.4494779   2.91731438]
#  [ 9.25676035 -2.33887834]
#  [-1.28588328  7.87003554]
#  [ 1.9970182   0.8253682 ]
#  [ 0.91291817  4.29862073]]

# %%
kmeans.inertia_
# Out:
# 678.2342614002728

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 3, 4, 4, 1, 4, 4, 3, 1, 2, 3, 4, 4, 4, 1, 3, 4, 0, 1, 1,
#        0, 3, 0, 2, 0, 2, 1, 1, 4, 1, 1, 3, 1, 1, 3, 2, 1, 1, 3, 0, 2, 3,
#        4, 0, 4, 0, 4, 2, 3, 4, 2, 4, 4, 1, 4, 1, 4, 3, 4, 1, 1, 4, 4, 2,
#        2, 3, 0, 1, 0, 4, 1, 0, 3, 1, 1, 3, 3, 3, 2, 0, 1, 0, 3, 4, 2, 1,
#        1, 4, 4, 0, 2, 3, 4, 4, 2, 0, 0, 0, 2, 0, 0, 1, 0, 4, 4, 1, 0, 4,
#        4, 4, 0, 4, 3, 4, 1, 0, 1, 4, 4, 0, 2, 2, 0, 4, 3, 3, 2, 1, 3, 2,
#        3, 1, 2, 4, 3, 4, 4, 4, 3, 1, 1, 1, 0, 3, 0, 4, 2, 2, 3, 4, 3, 1,
#        3, 4, 3, 4, 3, 1, 2, 4, 0, 2, 3, 3, 4, 4, 4, 4, 0, 2, 1, 4, 3, 1,
#        0, 0, 3, 1, 1, 3, 2, 2, 4, 2, 4, 3, 4, 2, 2, 2, 0, 3, 2, 1, 4, 1,
#        0, 2, 0, 1, 1, 3, 1, 0, 2, 1, 4, 2, 2, 3, 1, 2, 4, 2, 4, 1, 2, 4,
#        0, 0, 3, 3, 1, 3, 1, 3, 4, 3, 2, 1, 4, 4, 2, 3, 1, 1, 4, 3, 4, 4,
#        0, 1, 1, 2, 3, 0, 0, 4, 0, 0, 3, 3, 1, 1, 3, 2, 4, 3, 1, 1, 4, 0,
#        4, 3, 1, 4, 0, 1, 0, 4, 0, 1, 1, 0, 4, 1, 3, 1, 1, 2, 3, 3, 3, 2,
# ...

# %%
#plt.plot(x,y,'.')
plt.scatter(data[:,0], data[:,1], c=kmeans.labels_)
plt.plot(centroids[:,0], centroids[:, 1], 'r+')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')
